# %%
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import matplotlib.pyplot as plt
from torch.utils.data.sampler import SubsetRandomSampler
from torch.utils.data import DataLoader
from torchvision import datasets, transforms
import matplotlib.pyplot as plt
# %matplotlib inline
import torch.nn as nn
from torchsummary import summary

from skimage import io
import cv2
from skimage.color import gray2rgb
import pathlib

from skimage.metrics import normalized_root_mse

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os
os.chdir('/content/drive/MyDrive/Machine_Learning/Crack_Detection') 
# !pwd
# %ls
# Out:
# /content/drive/MyDrive/Machine_Learning/Crack_Detection
# Autoencoders_Conv2d.ipynb  data/

# %%
dir_data = pathlib.Path('data')
path = dir_data/'Negative'

i_0=1 #1rst image to read
i_1=1200 #last image to read

#Shape of an image
img_2 = io.imread(str(path/'%s%05d.tif') %("Neg_",i_0))
a1, b1 = img_2.shape
print('Image shape: %d, %d' %(a1,b1))

scale = 2
#Initialisation
train_images=np.zeros((i_1-i_0+1,int(a1/scale),int(b1/scale),3))
#Read images
for i in range (i_0, i_1+1):    
    img= io.imread(str(path /'%s%05d.tif') %("Neg_",i)) 
    img_rescaled = cv2.resize(img, (img.shape[0] // scale, img.shape[1] // scale), interpolation = cv2.INTER_LINEAR)
    train_images[i-i_0,:,:,:]= gray2rgb(img_rescaled)
print(path,"read")
print(train_images.shape)

train_images = (train_images).astype('float32')

#from skimage.util import crop
#train_images = crop(train_images, ((0, 0), (49, 50), (49, 50), (0,0)), copy=False)

train_images_T = np.transpose(train_images, (0, 3, 1, 2))
print(train_images.shape, train_images_T.shape)
# Out:
# Image shape: 512, 512
# data/Negative read
# (1200, 256, 256, 3)
# (1200, 256, 256, 3) (1200, 3, 256, 256)

# %%
def get_device():
    if torch.cuda.is_available():
        device = 'cuda:0'
    else:
        device = 'cpu'
    return device

Device = get_device()
print(Device)
# Out:
# cuda:0

# %%
train_loader = torch.utils.data.DataLoader(train_images_T, batch_size=32, num_workers=1,  shuffle=True)

#Utility functions to un-normalize and display an image
def imshow(img):
    plt.imshow((np.transpose(img, (1, 2, 0)))/255.)

#Obtain one batch of training images
dataiter = iter(train_loader)
images = dataiter.next()
images = images.numpy() # convert images to numpy for display

#Plot the images
fig = plt.figure(figsize=(8, 8))
# display 9 images
for idx in np.arange(9):
    ax = fig.add_subplot(3, 3, idx+1, xticks=[], yticks=[])
    imshow(images[idx])

# %%
#Define the Convolutional Autoencoder
class ConvAutoencoder(nn.Module):
    def __init__(self):
        super(ConvAutoencoder, self).__init__()
        
        self.main = nn.Sequential(
            # input going into a convolution
            nn.Conv2d(3, 64, 3, padding=1, bias=False),
            nn.BatchNorm2d(64),
            nn.ReLU(True),
            # Pooling
            nn.MaxPool2d(2, 2),
            nn.Dropout(0.2),
            #
            nn.Conv2d(64, 64*2, 3, padding=1, bias=False),
            nn.BatchNorm2d(64*2),
            nn.ReLU(True),
            # Pooling
            nn.MaxPool2d(2, 2),
            nn.Dropout(0.2),
            #
            nn.Conv2d(64*2, 64*3, 3, padding=1, bias=False),
            nn.BatchNorm2d(64*3),
            nn.ReLU(True),
            # Pooling
            nn.MaxPool2d(2, 2),
            nn.Dropout(0.2),
            #
            nn.Conv2d(64*3, 64*4, 3, padding=1, bias=False),
            nn.BatchNorm2d(64*4),
            nn.ReLU(True),
            # Pooling
            nn.MaxPool2d(2, 2),
            nn.Dropout(0.2),
            #
            nn.Conv2d(64*4, 64*5, 3, padding=1, bias=False),
            nn.BatchNorm2d(64*5),
            nn.ReLU(True),
            # Pooling
            nn.MaxPool2d(2, 2),
            nn.Dropout(0.2),  
            #
            nn.Conv2d(64*5, 64*6, 3, padding=1, bias=False),
            nn.BatchNorm2d(64*6),
            nn.ReLU(True),
            # Pooling
            nn.MaxPool2d(2, 2),
            nn.Dropout(0.2), 
            #
            nn.Conv2d(64*6, 100, 3, padding=1, bias=False),
            nn.BatchNorm2d(100),
            nn.ReLU(True),
            # Pooling
            nn.MaxPool2d(2, 2),
            nn.Dropout(0.2),    
            # state size. 64*6 
            nn.ConvTranspose2d(100, 64*6, 4, stride =2, padding=1, bias=False),
            nn.BatchNorm2d(64*6),
            nn.Dropout(0.2),
            nn.ReLU(True),
            # state size. 64*5 
            nn.ConvTranspose2d(64*6, 64*5, 4, stride =2, padding=1, bias=False),
            nn.BatchNorm2d(64*5),
            nn.Dropout(0.2),
            nn.ReLU(True),                                                                  
            # state size. 64*4 
            nn.ConvTranspose2d(64*5, 64*4, 4, stride =2, padding=1, bias=False),
            nn.BatchNorm2d(64*4),
            nn.Dropout(0.2),
            nn.ReLU(True),
            # state size. 64*3 
            nn.ConvTranspose2d(64*4, 64*3, 4, stride =2, padding=1, bias=False),
            nn.BatchNorm2d(64*3),
            nn.Dropout(0.2),
            nn.ReLU(True),
            # state size. 64*2 
            nn.ConvTranspose2d(64*3, 64*2, 4, stride =2, padding=1, bias=False),
            nn.BatchNorm2d(64*2),
            nn.Dropout(0.2),
            nn.ReLU(True),
            # state size. 64*1 
            nn.ConvTranspose2d(64*2, 64, 4, stride =2, padding=1, bias=False),
            nn.BatchNorm2d(64),
            nn.Dropout(0.2),
            nn.ReLU(True),
            # state size. outchanels = 3           
            nn.ConvTranspose2d(64, 3, 4, stride =2, padding=1, bias=False),
            #nn.Sigmoid()
        )

    def forward(self, input):
        return self.main(input)

#Instantiate the model
model = ConvAutoencoder()
model.to(Device)

summary(model,(3,512//scale,512//scale))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ...
#             Conv2d-1         [-1, 64, 256, 256]           1,728
#        BatchNorm2d-2         [-1, 64, 256, 256]             128
#               ReLU-3         [-1, 64, 256, 256]               0
#          MaxPool2d-4         [-1, 64, 128, 128]               0
#            Dropout-5         [-1, 64, 128, 128]               0
#             Conv2d-6        [-1, 128, 128, 128]          73,728
#        BatchNorm2d-7        [-1, 128, 128, 128]             256
#               ReLU-8        [-1, 128, 128, 128]               0
#          MaxPool2d-9          [-1, 128, 64, 64]               0
#           Dropout-10          [-1, 128, 64, 64]               0
#            Conv2d-11          [-1, 192, 64, 64]         221,184
#       BatchNorm2d-12          [-1, 192, 64, 64]             384
#              ReLU-13          [-1, 192, 64, 64]               0
# ...

# %%
#Loss function
criterion = nn.MSELoss()#nn.BCELoss()#torch.nn.BCEWithLogitsLoss()#

#Optimizer
optimizer = torch.optim.Adam(model.parameters(), lr=0.00005)

batch_size = 32

# %%
#Epochs
n_epochs = 1000

for epoch in range(1, n_epochs+1):
    # monitor training loss
    train_loss = 0.0

    #Training
    for data in train_loader:
        images = data#, _
        images = images.to(Device)
        optimizer.zero_grad()
        outputs = model(images)
        loss = criterion(outputs, images)
        loss.backward()
        optimizer.step()
        train_loss += loss.item()*images.size(0)
          
    train_loss = train_loss/len(train_loader)
    print('Epoch: {} \tTraining Loss: {:.6f}'.format(epoch, train_loss))
# Out:
# Epoch: 1 	Training Loss: 226628.155839
# Epoch: 2 	Training Loss: 224771.242599
# Epoch: 3 	Training Loss: 223602.217722
# Epoch: 4 	Training Loss: 222556.270148

# %%
#Batch of test images
dataiter = iter(train_loader)
images = dataiter.next()

#Sample outputs
output = model(images.to(Device))

output = output.cpu()
images = images.numpy()

output = output.view(batch_size, 3, 512//scale, 512//scale)
output = output.detach().numpy()

#Original Images
print("Original Images")
fig, axes = plt.subplots(nrows=1, ncols=10, sharex=True, sharey=True, figsize=(60,5))
for idx in np.arange(10):
    ax = fig.add_subplot(1, 10, idx+1, xticks=[], yticks=[])
    imshow(images[idx])
plt.show()

#Reconstructed Images
print('Reconstructed Images')
fig, axes = plt.subplots(nrows=1, ncols=10, sharex=True, sharey=True, figsize=(60,5))
for idx in np.arange(10):
    ax = fig.add_subplot(1, 10, idx+1, xticks=[], yticks=[])
    imshow(output[idx])
plt.show() 

#Loss
Loss_N =[]
for idx in np.arange(batch_size):
  Loss_N.append(normalized_root_mse(images[idx],output[idx]))
print(len(Loss_N), Loss_N)

# %%
dir_data = pathlib.Path('data')
path = dir_data/'Positive'

i_0=1 #1rst image to read
i_1=64 #last image to read

#Initialisation
test_images=np.zeros((i_1-i_0+1,a1//scale,b1//scale,3))
#Read images
for i in range (i_0, i_1+1):    
    img= io.imread(str(path /'%s%05d.tif') %("Pos_",i)) 
    img_rescaled = cv2.resize(img, (img.shape[0] // scale, img.shape[1] // scale), interpolation = cv2.INTER_LINEAR)
    test_images[i-i_0,:,:,:]= gray2rgb(img_rescaled)#
print(path,"read")
print(test_images.shape)

test_images = (test_images).astype('float32')

test_images_T = np.transpose(test_images, (0, 3, 1, 2))
print(test_images.shape, test_images_T.shape)

test_loader = torch.utils.data.DataLoader(test_images_T, batch_size=32, num_workers=1)

Loss_P =[]
for data in test_loader:
    images = data
    #Sample outputs
    output = model(images.to(device))

    output = output.cpu()
    images = images.numpy()
    output = output.view(batch_size, 3, img.shape[0] // scale, img.shape[1] // scale)
    output = output.detach().numpy()

    #Original Images
    print("Original Images")
    fig, axes = plt.subplots(nrows=1, ncols=10, sharex=True, sharey=True, figsize=(60,5))
    for idx in np.arange(10):
        ax = fig.add_subplot(1, 10, idx+1, xticks=[], yticks=[])
        imshow(images[idx])
    plt.show()

    #Reconstructed Images
    print('Reconstructed Images')
    fig, axes = plt.subplots(nrows=1, ncols=10, sharex=True, sharey=True, figsize=(60,5))
    for idx in np.arange(10):
        ax = fig.add_subplot(1, 10, idx+1, xticks=[], yticks=[])
        imshow(output[idx])
    plt.show() 

    #Loss 
    for idx in np.arange(batch_size):
      Loss_P.append(normalized_root_mse(images[idx],output[idx]))
print(len(Loss_P), Loss_P)

# %%
dir_data = pathlib.Path('Concrete_Crack_Images_for_Classification')
path = dir_data/'Test' #Positive

i_0=1 #1rst image to read
i_1=192 #last image to read

#Shape of an image
img_2 = io.imread(str(path/'%05d.jpg') %(i_0+9808))
a1, b1, c1= img_2.shape
print('Image shape: %d, %d, %d' %(a1,b1,c1))

#Initialisation
test_images_P=np.zeros((i_1-i_0+1,a1,b1,3))
#Read images
for i in range (i_0, i_1+1):    
    img= io.imread(str(path /'%05d.jpg') %(i+9808)) 
    img_rescaled = cv2.resize(img, (img.shape[0] // scale, img.shape[1] // scale), interpolation = cv2.INTER_LINEAR)
    test_images_P[i-i_0,:,:,:]= img_rescaled
print(path,"read")
print(test_images_P.shape)

test_images_P = (test_images_P).astype('float32')
test_images_T = np.transpose(test_images_P, (0, 3, 1, 2))
print(test_images_P.shape, test_images_T.shape)

batch_size = 64
test_loader_P = torch.utils.data.DataLoader(test_images_T, batch_size=batch_size, num_workers=1)

Loss_PT =[]
for data in test_loader_P:
    images = data
    #Sample outputs
    output = model(images.to(device))

    output = output.cpu()
    images = images.numpy()
    output = output.view(batch_size, 3, img.shape[0] // scale, img.shape[1] // scale)
    output = output.detach().numpy()

    #Original Images
    print("Original Images")
    fig, axes = plt.subplots(nrows=1, ncols=10, sharex=True, sharey=True, figsize=(60,5))
    for idx in np.arange(10):
        ax = fig.add_subplot(1, 10, idx+1, xticks=[], yticks=[])
        imshow(images[idx])
    plt.show()

    #Reconstructed Images
    print('Reconstructed Images')
    fig, axes = plt.subplots(nrows=1, ncols=10, sharex=True, sharey=True, figsize=(60,5))
    for idx in np.arange(10):
        ax = fig.add_subplot(1, 10, idx+1, xticks=[], yticks=[])
        imshow(output[idx])
    plt.show() 

    #Loss 
    for idx in np.arange(batch_size):
      Loss_PT.append(normalized_root_mse(images[idx],output[idx]))
print(len(Loss_PT), Loss_PT)

# %%
dir_data = pathlib.Path('Concrete_Crack_Images_for_Classification')
path = dir_data/'Test' #Negative

i_0=1 #1rst image to read
i_1=192 #last image to read

#Shape of an image
img_2 = io.imread(str(path/'%05d.jpg') %(i_0+19808))
a1, b1, c1= img_2.shape
print('Image shape: %d, %d, %d' %(a1,b1,c1))

#Initialisation
test_images_N=np.zeros((i_1-i_0+1,a1,b1,3))
#Read images
for i in range (i_0, i_1+1):    
    img= io.imread(str(path /'%05d.jpg') %(i+19808)) 
    img_rescaled = cv2.resize(img, (img.shape[0] // scale, img.shape[1] // scale), interpolation = cv2.INTER_LINEAR)
    test_images_N[i-i_0,:,:,:]= img_rescaled
print(path,"read")
print(test_images_N.shape)

test_images_N = (test_images_N).astype('float32')

batch_size = 64
test_loader_N = torch.utils.data.DataLoader(test_images_T, batch_size=batch_size, num_workers=1)

Loss_NT =[]
for data in test_loader_N:
    images = data
    #Sample outputs
    output = model(images.to(device))

    output = output.cpu()
    images = images.numpy()
    output = output.view(batch_size, 3, img.shape[0] // scale, img.shape[1] // scale)
    output = output.detach().numpy()

    #Original Images
    print("Original Images")
    fig, axes = plt.subplots(nrows=1, ncols=10, sharex=True, sharey=True, figsize=(60,5))
    for idx in np.arange(10):
        ax = fig.add_subplot(1, 10, idx+1, xticks=[], yticks=[])
        imshow(images[idx])
    plt.show()

    #Reconstructed Images
    print('Reconstructed Images')
    fig, axes = plt.subplots(nrows=1, ncols=10, sharex=True, sharey=True, figsize=(60,5))
    for idx in np.arange(10):
        ax = fig.add_subplot(1, 10, idx+1, xticks=[], yticks=[])
        imshow(output[idx])
    plt.show() 

    #Loss 
    for idx in np.arange(batch_size):
      Loss_NT.append(normalized_root_mse(images[idx],output[idx]))
print(len(Loss_NT), Loss_NT)

# %%
print(np.min(Loss_PT))
print(np.max(Loss_NT))
